# %%
import pandas as pd

# %%
df = pd.read_pickle('./df.pkl')

# %%
df.sample(10)
# Out:
#             gameId  gameDuration summonerName  \
# 105168  5545463612          1796         jo진호
# 120656  5545457504          1270     서폿하면바텀터짐
# 226513  5509630890          1587   V1ta Felix
# 276260  5532218229          2015     자비로운 베짱이
# 241174  5515174522          1631        자살할꺼야
# 124916  5545932788          1521      반사회적 티어
# 252245  5504902625          2554      랭겜잡는데3초
# 151595  5546032019          1589          초웃겨
# 170889  5522288983          2005         95cm
# 191281  5522190434          1692     어푸푸 어푸어푸
#
#                                                     puuid  summonerLevel  \
# 105168  NKB9hLcKyaVfjFOwaAfvoSeEIlZwe2yzC2g03TUGCLQKlr...            357
# 120656  HnEk-a0fT3hKvUAcPsWWQw4EaH-SPt4B1iKWd5-Z25XCPC...            217
# 226513  ILG_HRRhfV1h22xwCdtYzQyN-DOTyLOY2bFO_zzDl-MUDR...             72
# 276260  X3lVNaRtogj4XnnSRGVLcQyq-fNhfirU1CdhB5ljhBQEWE...            627
# 241174  cjpbxt2Xp7acLBLPEdOOqHuDRTNBAEFtXRT60KIumO1ENd...            363
# ...

# %%
df.loc[(df['summonerName'].str.contains('손인욱')), 'summonerName'].unique()
# Out:
# array(['손인욱 fan', '용암동손인욱남친', '손인욱과 김찬호', ' 손인욱  귀여워', '노랑시티 손인욱',
#        '손인욱김찬호', '정상길 손인욱', '이렐 장인 손인욱', '손인욱식야리돌림', '고2 손인욱', '단백질도둑손인욱',
#        '애국보수 손인욱', '상현의 1 손인욱', 'HLE 손인욱', ' 사나이손인욱', '곰박사 손인욱',
#        '손인욱사랑해요', '손흥민보단손인욱', '보급형 손인욱', '손인욱이될래요', '별 수호자 손인욱',
#        '손인욱의 아들', '하현의1 손인욱', '장래희망 손인욱', '명서동손인욱'], dtype=object)

# %%
# Out:
# 33
